# %% [markdown]
# <a href="https://colab.research.google.com/github/znumunz/Prem1/blob/main/Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
bfs_outcome_df = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv')

# %%
bfs_outcome_df.head(5)
# Out:
#                                             Crime ID    Month  \
# 0  52929bd151e1826911839f4b57e493df892c8ff3fc0952...  2025-01
# 1  29e1591b3a59ab11db949797202743d4eb2a8e009648e0...  2025-01
# 2  618de6846fec73e8ce3cdfef1e1f83a56371214e56d2ee...  2025-01
# 3  ac32fb4e82430d595494425c42d9c456f1a07b24964d61...  2025-01
# 4  b861fd8847708c11a0e49b6d01ac11fbb91f26bfac78c8...  2025-01
#
#            Reported by         Falls within  Longitude   Latitude  \
# 0  Bedfordshire Police  Bedfordshire Police  -0.271341  52.057223
# 1  Bedfordshire Police  Bedfordshire Police  -0.431611  52.005211
# 2  Bedfordshire Police  Bedfordshire Police  -0.564702  51.877476
# 3  Bedfordshire Police  Bedfordshire Police  -0.322350  52.035383
# 4  Bedfordshire Police  Bedfordshire Police  -0.524683  51.903161
#
#                        Location  LSOA code                  LSOA name  \
# 0  On or near King George Close  E01017414  Central Bedfordshire 010E
# ...

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
path_to_stop_and_search = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %% [markdown]
# ## load data to memory

# %%
stop_and_search = pd.read_csv(path_to_stop_and_search)

# %%
stop_and_search.head(3)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
# 2                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
#
#                                          Legislation   Object of search  \
# ...

# %%
stop_and_search.head(3)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
# 2                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
#
#                                          Legislation   Object of search  \
# ...

# %%
df = stop_and_search

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Type                                      387 non-null    object
#  1   Date                                      387 non-null    object
#  2   Part of a policing operation              387 non-null    bool
#  3   Policing operation                        0 non-null      float64
#  4   Latitude                                  321 non-null    float64
#  5   Longitude                                 321 non-null    float64
#  6   Gender                                    327 non-null    object
#  7   Age range                                 351 non-null    object
#  8   Self-defined ethnicity                    356 non-null    object
#  9   Officer-defined ethnicity                 353 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Type                                          3
# Date                                        313
# Part of a policing operation                  2
# Policing operation                            0
# Latitude                                    188
# Longitude                                   188
# Gender                                        2
# Age range                                     5
# Self-defined ethnicity                       18
# Officer-defined ethnicity                     4
# Legislation                                   3
# Object of search                              5
# Outcome                                       5
# Outcome linked to object of search            2
# Removal of more than just outer clothing      2
# dtype: int64

# %%
print(df['Type'].unique())
# Out:
# ['Person search' 'Vehicle search' 'Person and Vehicle search']

# %%
df.shape
# Out:
# (387, 15)

# %%
display(df)
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
stop_and_search['Outcome'][0]
# Out:
# 'Arrest'

# %%
stop_and_search['Outcome'][99]
# Out:
# 'A no further action disposal'

# %%
fd = df.head(3)
fd
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
# 2                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
#
#                                          Legislation   Object of search  \
# ...

# %%
fd["DATA"] = 'ddd'
# Out:
# /tmp/ipython-input-674864406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd["DATA"] = 'ddd'

# %%
fd
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
# 2                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
# 2                     White
#
#                                          Legislation   Object of search  \
# ...

# %%
data = []

# %% [markdown]
# #### .iloc

# %%
df1 = df[['Type']]
# Out:
#                           Type
# 0                Person search
# 1                Person search
# 2                Person search
# 3                Person search
# 4                Person search
# ..                         ...
# 382              Person search
# 383              Person search
# 384              Person search
# 385              Person search
# 386  Person and Vehicle search
#
# [387 rows x 1 columns]

# %%
# Out:
#             Type                       Date  Part of a policing operation  \
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 1                 NaN  52.132059    -0.2966    Male     10-17
# 2                 NaN  52.132059    -0.2966    Male     10-17
# 3                 NaN  52.132059    -0.2966  Female     10-17
# 4                 NaN  52.132059    -0.2966    Male     10-17
#
#                               Self-defined ethnicity  \
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...
#
# ...

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title','type','creator','subject','spatial']]
smaller_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-82-2459510250.py in <cell line: 0>()
# ----> 1 smaller_table = folk_df[:,['title','type','creator','subject','spatial']]
#       2 smaller_table
#
# NameError: name 'folk_df' is not defined

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
#df.iloc[:5,0:1]
# df.loc[['Type','Date','Gender']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-84-2395342498.py in <cell line: 0>()
#       1 #df.iloc[:5,0:1]
# ----> 2 df.loc[['Type','Date','Gender']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
# -> 1420                 return self._getitem_iterable(key, axis=axis)
#    1421
# ...

# %%
folk_df.iloc[1:5,:]
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# #### อยากได้ นิทานที่เป็นมุขตลก

# %%
df['Type']=='Person search'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386    False
# Name: Type, Length: 387, dtype: bool

# %%
df[df['Type']!='Person search',['Type','Date']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386     True
# Name: Type, Length: 387, dtype: bool, ['Type', 'Date'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipython-input-111-2747135242.py in <cell line: 0>()
# ...

# %%
df[df['Type']=='Person search'].iloc[:5,4:5].sort_values('Latitude',ascending=False)
# Out:
#     Latitude
# 1  52.132059
# 3  52.132059
# 2  52.132059
# 4  52.132059
# 0  51.881481

# %% [markdown]
# # quiz 6 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (226-25)*[False]

# %%
folk_df[list_log1+list_logM+list_log2]
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are True, the rest are False.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (226-25)*[False]

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][0]
# Out:
# '<p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;เราจะพาไปตั้งวงดนตรีจะไปไหม?&quot; &quot;เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งพูดขึ้นมาว่า&nbsp;&nbsp;&quot;นายจะร้องได้ไหม?&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; อีกคนตอบ &quot;มันจะยากอะไร&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า &quot;นั่นช้างหรอ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง&nbsp;เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า</p>\n\n<p>
# ...

# %% [markdown]
# ## Quiz 8-2

# %%
# Define file paths for February 2025
path_to_london = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-city-of-london-stop-and-search.csv'
path_to_cambridge = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-cambridgeshire-stop-and-search.csv'

# Load data into DataFrames
london_df = pd.read_csv(path_to_london)
cambridge_df = pd.read_csv(path_to_cambridge)

# Filter for "White - English/Welsh/Scottish/Northern Irish/British"
london_white_english = london_df[london_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']
cambridge_white_english = cambridge_df[cambridge_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']

# Compare and print the results
london_count = len(london_white_english)
cambridge_count = len(cambridge_white_english)

if london_count > cambridge_count:
    print(f"City of London has more White, English people stopped and searched by {london_count - cambridge_count}.")
elif cambridge_count > london_count:
    print(f"Cambridgeshire has more White, English people stopped and searched by {cambridge_count - london_count}.")
else:
    print("Both have the same number of White, English people stopped and searched.")

print(f"City of London: {london_count}")
print(f"Cambridgeshire: {cambridge_count}")
# Out:
# Cambridgeshire has more White, English people stopped and searched by 54.
# City of London: 15
# Cambridgeshire: 69

# %% [markdown]
# # WH 4

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import os

# ฟังก์ชันอ่านไฟล์ทั้งหมด เก็บข้อมูลลง list ที่เพิ่มคอลัมน์ชื่อเมืองเข้าไป
def read_all_data(base_path):
    all_dfs = []  # สร้าง list เปล่าเพื่อเอาไว้เก็บไฟล์ทั้งหมด
    months = os.listdir(base_path)  # สร้างตัวแปรเพื่อเก็บโฟลเดอร์ดือนทั้งหมด

    for month in months:
        month_path = os.path.join(base_path, month) # เชื่อม basepath กับชื่อเดือนเป็นเส้นทางของแต่ละเดือน
        files = os.listdir(month_path) #สร้างตัวแปรเพื่อเก็บชื่อไฟล์ทั้งหมดที่อยู่ในเดือนนั้น
        for file in files:
            if 'stop-and-search' in file: #ดำเนินการเฉพาะไฟล์ 'stop-and-search' ทุกเมือง
                filepath = os.path.join(month_path, file) # สร้างไฟล์พาทที่มีไฟล์เฉพาะ stop-and-search
                df = pd.read_csv(filepath) # สร้าตัวแปรมารับตาราง
                city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1] # เลือกมาแค่ชื่อเมือง
                df['Police Force'] = city # นำชื่อเมืองมาสร้างคอลัมน์ใหม่ใน df
                all_dfs.append(df) #เพิ่ม df ใน all_dfs

    return all_dfs #คืนค่าตารางทั้งหมดที่้พิ่มเข้ามาเรือยๆ

# ฟังก์ชันนับจำนวนคนเชื้อสายเอเชีย รวมทุกไฟล์
def count_asian_people(all_dfs):
    asian_counts = {}  # สร้าง dictionary ว่าง เพื่อเก็บจำนวนคนเชื้อสายเอเชียของแต่ละเมือง

    for df in all_dfs:  # วนลูปดูข้อมูลในแต่ละ DataFrame ที่เก็บมาใน list
        for i in range(len(df)):  # วนลูปทีละแถวใน DataFrame นั้น
            row = df.iloc[i]  # ดึงแถวที่ i ออกมาเป็น Series (เหมือน dictionary ของแต่ละแถว)
            ethnicity = str(row.get('Self-defined ethnicity', ''))  # อ่านคอลัมน์ 'Self-defined ethnicity' ของแถวนี้ ถ้าไม่มีให้เป็น '' (ค่าว่าง)

            if 'Asian' in ethnicity:  # ถ้าค่าในคอลัมน์นั้นมีคำว่า 'Asian' อยู่ (หมายถึงคนเชื้อสายเอเชีย)
                city = row['Police Force']  # อ่านชื่อเมืองจากคอลัมน์ 'Police Force' ของแถวนั้น

                if city not in asian_counts:  # ถ้าเมืองนี้ยังไม่เคยเจอใน dictionary
                    asian_counts[city] = 0     # สร้างค่าเริ่มต้นเป็น 0

                asian_counts[city] += 1  # เพิ่มจำนวนคนเชื้อสายเอเชียในเมืองนั้น 1 คน

    return asian_counts  # คืนค่า dictionary ที่เก็บจำนวนคนเชื้อสายเอเชียของแต่ละเมือง

# ส่วนหลักของโปรแกรม
base_path = '/content/drive/MyDrive/MyPython&DataViz2025/Data/'

# อ่านข้อมูลจากไฟล์ทั้งหมด
dataframes = read_all_data(base_path)

# นับคนเชื้อสายเอเชียรวมทั้ง 5 เดือน
counts = count_asian_people(dataframes)

# หามากที่สุดและน้อยที่สุด
most_city = max(counts, key=counts.get)
fewest_city = min(counts, key=counts.get)

# แสดงผลทุกเมือง
print("รวมจำนวนการเรียกค้นผู้มีเชื้อสายเอเชียในแต่ละเมือง (รวม 5 เดือน):\n")
for city in sorted(counts, key=counts.get, reverse=True):
    print(f"{city}: {counts[city]}")

print("\n====== สรุป ======")
print(f"เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด: {most_city} ({counts[most_city]})")
print(f"เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด: {fewest_city} ({counts[fewest_city]})")
# Out:
# Mounted at /content/drive
# รวมจำนวนการเรียกค้นผู้มีเชื้อสายเอเชียในแต่ละเมือง (รวม 5 เดือน):
#
# west-midlands: 2104
# metropolitan: 2033
# lancashire: 1301
# thames-valley: 718
# west-yorkshire: 537
# btp: 524
# south-yorkshire: 443
# merseyside: 361
# bedfordshire: 322
# hampshire: 275
# leicestershire: 226
# northumbria: 209
# staffordshire: 205
# hertfordshire: 182
# essex: 170
# kent: 162
# surrey: 152
# cheshire: 149
# cleveland: 125
# cambridgeshire: 120
# cumbria: 94
# south-wales: 91
# west-mercia: 85
# city-of-london: 84
# derbyshire: 83
# sussex: 82
# nottinghamshire: 61
# northamptonshire: 58
# avon-and-somerset: 54
# warwickshire: 46
# devon-and-cornwall: 35
# gloucestershire: 27
# dyfed-powys: 24
# suffolk: 22
# north-wales: 19
# dorset: 18
# norfolk: 10
# durham: 5
#
# ====== สรุป ======
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด: west-midlands (2104)
# เมืองที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด: durham (5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# %%
months = os.listdir(base_path)  # โฟลเดอร์เดือนทั้งหมด
months
# Out:
# ['2025-05', '2025-04', '2025-01', '2025-02', '2025-03']

# %%
all_files = []

for month in months:
    month_path = os.path.join(base_path, month)
    files = os.listdir(month_path)
    for f in files:
        all_files.append(f)  # เก็บเดือนและชื่อไฟล์
all_files
# Out:
# ['2025-05-thames-valley-stop-and-search.csv',
#  '2025-05-west-midlands-stop-and-search.csv',
#  '2025-05-west-yorkshire-stop-and-search.csv',
#  '2025-05-warwickshire-stop-and-search.csv',
#  '2025-05-northamptonshire-stop-and-search.csv',
#  '2025-05-north-wales-stop-and-search.csv',
#  '2025-05-surrey-stop-and-search.csv',
#  '2025-05-staffordshire-stop-and-search.csv',
#  '2025-05-west-mercia-stop-and-search.csv',
#  '2025-05-nottinghamshire-stop-and-search.csv',
#  '2025-05-suffolk-stop-and-search.csv',
#  '2025-05-south-wales-stop-and-search.csv',
#  '2025-05-south-yorkshire-stop-and-search.csv',
#  '2025-05-city-of-london-street.csv',
#  '2025-05-warwickshire-outcomes.csv',
#  '2025-05-devon-and-cornwall-stop-and-search.csv',
#  '2025-05-gwent-outcomes.csv',
#  '2025-05-sussex-stop-and-search.csv',
#  '2025-05-hertfordshire-stop-and-search.csv',
#  '2025-05-cumbria-stop-and-search.csv',
#  '2025-05-norfolk-stop-and-search.csv',
#  '2025-05-city-of-london-outcomes.csv',
# ...

# %%
filepaths = []  # เปลี่ยนชื่อตัวแปรเพื่อความเข้าใจชัดเจน

for file in all_files:
    if 'stop-and-search' in file:
        filepath = os.path.join(month_path, file)
        filepaths.append(filepath)

# แสดงทั้งหมด
for path in filepaths:
    print(path)
# Out:
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-thames-valley-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-west-midlands-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-west-yorkshire-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-warwickshire-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-northamptonshire-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-north-wales-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-surrey-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-staffordshire-stop-and-search.csv
# /content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-05-west-mercia-stop-and-search.csv
# ...

# %%
all_dfs = []

df = pd.read_csv(filepath) # สร้าตัวแปรมารับตาราง
city = file.replace('-stop-and-search.csv', '').split('-', 2)[-1] # เลือกมาแค่ชื่อเมือง
df['Police Force'] = city # นำชื่อเมืองมาสร้างคอลัมน์ใหม่ใน df
all_dfs.append(df)
all_dfs
# Out:
# [                          Type                       Date  \
#  0                Person search  2025-03-01T01:30:00+00:00
#  1                Person search  2025-03-01T10:32:00+00:00
#  2                Person search  2025-03-01T10:32:00+00:00
#  3                Person search  2025-03-01T15:47:00+00:00
#  4                Person search  2025-03-01T15:47:00+00:00
#  ..                         ...                        ...
#  372              Person search  2025-03-30T21:06:00+00:00
#  373              Person search  2025-03-30T22:02:00+00:00
#  374  Person and Vehicle search  2025-03-30T23:11:00+00:00
#  375  Person and Vehicle search  2025-03-30T23:11:00+00:00
#  376  Person and Vehicle search  2025-03-31T17:10:00+00:00
#
#       Part of a policing operation  Policing operation   Latitude  Longitude  \
#  0                           False                 NaN  53.978977  -2.605049
#  1                           False                 NaN  54.014901  -2.898293
# ...

# %%
Ex = pd.concat(all_dfs, ignore_index=True)
Ex
# Out:
#                           Type                       Date  \
# 0                Person search  2025-03-01T01:30:00+00:00
# 1                Person search  2025-03-01T10:32:00+00:00
# 2                Person search  2025-03-01T10:32:00+00:00
# 3                Person search  2025-03-01T15:47:00+00:00
# 4                Person search  2025-03-01T15:47:00+00:00
# ..                         ...                        ...
# 372              Person search  2025-03-30T21:06:00+00:00
# 373              Person search  2025-03-30T22:02:00+00:00
# 374  Person and Vehicle search  2025-03-30T23:11:00+00:00
# 375  Person and Vehicle search  2025-03-30T23:11:00+00:00
# 376  Person and Vehicle search  2025-03-31T17:10:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  53.978977  -2.605049
# 1                           False                 NaN  54.014901  -2.898293
# ...

# %%
len(df)
# Out:
# 377

# %%
row = df.iloc[0]
row
# Out:
# Type                                                                            Person search
# Date                                                                2025-03-01T01:30:00+00:00
# Part of a policing operation                                                            False
# Policing operation                                                                        NaN
# Latitude                                                                            53.978977
# Longitude                                                                           -2.605049
# Gender                                                                                   Male
# Age range                                                                               18-24
# Self-defined ethnicity                      White - English/Welsh/Scottish/Northern Irish/...
# Officer-defined ethnicity                                                               White
# ...

# %%
ethnicity = str(row.get('Self-defined ethnicity', ''))
ethnicity
# Out:
# 'White - English/Welsh/Scottish/Northern Irish/British'

# %%
if 'Asian' in ethnicity:
                city = row['Police Force']
city
# Out:
# 'durham'

# %%
asian_counts = {}
if city not in asian_counts:  # ถ้าเมืองนี้ยังไม่เคยเจอใน dictionary
    asian_counts[city] = 0     # สร้างค่าเริ่มต้นเป็น 0

asian_counts[city] += 1  # เพิ่มจำนวนคนเชื้อสายเอเชียในเมืองนั้น 1 คน

asian_counts  # คืนค่า dictionary ที่เก็บจำนวนคนเชื้อสายเอเชียของแต่ละเมือง
# Out:
# {'durham': 1}

# %%
most_city_Ex = max(asian_counts)
most_city_Ex
# Out:
# 'durham'

# %%
most_city = max(asian_counts, key=asian_counts.get)
most_city
# Out:
# 'durham'

# %%
asian_counts[most_city]
# Out:
# 1

# %% [markdown]
# # HW5
# HW5 (เดี่ยว) แก้จาก code เดิม ยอดรวมทุกเมือง เดือนไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import os

# ฟังก์ชันอ่านไฟล์ทั้งหมด เก็บข้อมูลลง list ที่เพิ่มคอลัมน์ชื่อเมืองเข้าไป
def read_all_data(base_path):
    all_dfs = []  # สร้าง list เปล่าเพื่อเอาไว้เก็บไฟล์ทั้งหมด
    months = os.listdir(base_path)  # สร้างตัวแปรเพื่อเก็บโฟลเดอร์ดือนทั้งหมด

    for month in months:
        month_path = os.path.join(base_path, month) # เชื่อม basepath กับชื่อเดือนเป็นเส้นทางของแต่ละเดือน
        files = os.listdir(month_path) #สร้างตัวแปรเพื่อเก็บชื่อไฟล์ทั้งหมดที่อยู่ในเดือนนั้น
        for file in files:
            if 'stop-and-search' in file: #ดำเนินการเฉพาะไฟล์ 'stop-and-search' ทุกเมือง
                filepath = os.path.join(month_path, file) # สร้างไฟล์พาทที่มีไฟล์เฉพาะ stop-and-search
                df = pd.read_csv(filepath) # สร้าตัวแปรมารับตาราง
                month = file.replace('-stop-and-search.csv', '').split('-', 2)[1] # เลือกมาแค่ชื่อเมือง
                df['Police Force'] = month # นำชื่อเมืองมาสร้างคอลัมน์ใหม่ใน df
                all_dfs.append(df) #เพิ่ม df ใน all_dfs

    return all_dfs #คืนค่าตารางทั้งหมดที่้พิ่มเข้ามาเรือยๆ

# ฟังก์ชันนับจำนวนคนเชื้อสายเอเชีย รวมทุกไฟล์
def count_asian_people(all_dfs):
    asian_counts = {}  # สร้าง dictionary ว่าง เพื่อเก็บจำนวนคนเชื้อสายเอเชียของแต่ละเมือง

    for df in all_dfs:  # วนลูปดูข้อมูลในแต่ละ DataFrame ที่เก็บมาใน list
        for i in range(len(df)):  # วนลูปทีละแถวใน DataFrame นั้น
            row = df.iloc[i]  # ดึงแถวที่ i ออกมาเป็น Series (เหมือน dictionary ของแต่ละแถว)
            ethnicity = str(row.get('Self-defined ethnicity', ''))  # อ่านคอลัมน์ 'Self-defined ethnicity' ของแถวนี้ ถ้าไม่มีให้เป็น '' (ค่าว่าง)

            if 'Asian' in ethnicity:  # ถ้าค่าในคอลัมน์นั้นมีคำว่า 'Asian' อยู่ (หมายถึงคนเชื้อสายเอเชีย)
                month = row['Police Force']  # อ่านชื่อเมืองจากคอลัมน์ 'Police Force' ของแถวนั้น

                if month not in asian_counts:  # ถ้าเมืองนี้ยังไม่เคยเจอใน dictionary
                    asian_counts[month] = 0     # สร้างค่าเริ่มต้นเป็น 0

                asian_counts[month] += 1  # เพิ่มจำนวนคนเชื้อสายเอเชียในเมืองนั้น 1 คน

    return asian_counts  # คืนค่า dictionary ที่เก็บจำนวนคนเชื้อสายเอเชียของแต่ละเมือง

# ส่วนหลักของโปรแกรม
base_path = '/content/drive/MyDrive/MyPython&DataViz2025/Data/'

# อ่านข้อมูลจากไฟล์ทั้งหมด
dataframes = read_all_data(base_path)

# นับคนเชื้อสายเอเชียรวมทั้ง 5 เดือน
counts = count_asian_people(dataframes)

# หามากที่สุดและน้อยที่สุด
most_city = max(counts, key=counts.get)
fewest_city = min(counts, key=counts.get)

# แสดงผลทุกเมือง
print("รวมจำนวนการเรียกค้นผู้มีเชื้อสายเอเชียในแต่เดือน (รวมทุกเมือง):\n")
for month in sorted(counts, key=counts.get, reverse=True):
    print(f"เดือน {month}: {counts[month]}")

print("\n====== สรุป ======")
print(f"เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด: {most_city} ({counts[most_city]})")
print(f"เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด: {fewest_city} ({counts[fewest_city]})")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# รวมจำนวนการเรียกค้นผู้มีเชื้อสายเอเชียในแต่เดือน (รวมทุกเมือง):
#
# เดือน 01: 2874
# เดือน 02: 2244
# เดือน 04: 2224
# เดือน 03: 2137
# เดือน 05: 1737
#
# ====== สรุป ======
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียมากที่สุด: 01 (2874)
# เดือนที่มีการเรียกค้นคนเชื้อสายเอเชียน้อยที่สุด: 05 (1737)

# %% [markdown]
# ### *ตรวจสอบ Missing*

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
path_to_stop_and_search = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
df = pd.read_csv(path_to_stop_and_search)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ### Drop แบบพิจารณาบาง Columns
#
# > Add blockquote

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# ###เลือกเฉาพคอลัมน์ที่เราสนใจก่อน ค่อย Drop

# %%
df[['Outcome','Type','Age range']]
# Out:
#                           Outcome                       Type Age range
# 0                          Arrest              Person search     25-34
# 1    A no further action disposal              Person search     10-17
# 2    A no further action disposal              Person search     10-17
# 3    A no further action disposal              Person search     10-17
# 4    A no further action disposal              Person search     10-17
# ..                            ...                        ...       ...
# 382  A no further action disposal              Person search   over 34
# 383  A no further action disposal              Person search     25-34
# 384          Community resolution              Person search   over 34
# 385  A no further action disposal              Person search     18-24
# 386  A no further action disposal  Person and Vehicle search     18-24
#
# [387 rows x 3 columns]

# %%
df[['Outcome','Type','Age range']].dropna()
# Out:
#                           Outcome                       Type Age range
# 0                          Arrest              Person search     25-34
# 1    A no further action disposal              Person search     10-17
# 2    A no further action disposal              Person search     10-17
# 3    A no further action disposal              Person search     10-17
# 4    A no further action disposal              Person search     10-17
# ..                            ...                        ...       ...
# 382  A no further action disposal              Person search   over 34
# 383  A no further action disposal              Person search     25-34
# 384          Community resolution              Person search   over 34
# 385  A no further action disposal              Person search     18-24
# 386  A no further action disposal  Person and Vehicle search     18-24
#
# [351 rows x 3 columns]

# %% [markdown]
# ## HW 5.1

# %%
# prompt: ลบ row ที่มีค่าว่างใน column description

folk_df = folk_df.dropna(subset=['description'])

# %%
# prompt: ลบ html tags และ html codes ออกจาก text ใน column description ใช้ beautifulsoup

from bs4 import BeautifulSoup

def remove_html_tags(text):
  soup = BeautifulSoup(text, "html.parser")
  cleaned_text = soup.get_text()
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_html_tags)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0          มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่...  นิทานพื้นบ้าน     ไทย
# 1        ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครอ...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['description'][0]
# Out:
# '\xa0 \xa0 \xa0 \xa0 มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า\n\n\xa0 \xa0 \xa0 \xa0"เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งพูดขึ้นมาว่า\xa0\xa0"นายจะร้องได้ไหม?"\n\n\xa0 \xa0 \xa0 \xa0 อีกคนตอบ "มันจะยากอะไร"\n\n\xa0 \xa0 \xa0 \xa0 เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0"หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง\xa0เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน\n\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า\n\n\xa0 \xa0 \xa0 \xa0 "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"\n\n\xa0 \xa0 \xa0 \xa0 คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า\n\n\xa0 \xa0 \xa0 \xa0 "ช้างนี่เหมือนสูบตีเหล็กนะ"\n\n\xa0 \xa0 \xa0 \xa0\xa0คนที
# ...

# %%
# prompt: ลบ \xa0 และ \n ออกไปด้วย

def remove_special_chars(text):
  cleaned_text = text.replace('\xa0', '')
  cleaned_text = cleaned_text.replace('\n', '')
  return cleaned_text

folk_df['description'] = folk_df['description'].apply(remove_special_chars)

# %%
folk_df['description'][0]
# Out:
# '    มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า   "เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"    ตาบอดคนหนึ่งพูดขึ้นมาว่า"นายจะร้องได้ไหม?"    อีกคนตอบ "มันจะยากอะไร"    เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า   "หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"    ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"    ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้างเจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน    ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า    "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"    คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า    "ช้างนี่เหมือนสูบตีเหล็กนะ"   คนที่สามเข้ามาทางด้านข้างของช้าง ก็จับดูทางด้านข้าง    "โอ้ ช้างนี่เหมือนผนังยุ้งข้าวเลย"     คนที่สี่เข้ามาถึง ก็จับไปโดนหูช้าง    "โอ้ ช้างนี่เหมือนภาชนะสำหรับฝัดข้าวเลย"     พอคนที่ห้าเข้ามาถึง ก็เข้าไปจับโดนมือช้างหรืองวงช้าง ก็พูดว่า    "โอ้ช้างนี่มันเหมือนปลิงเลย ปลิงตั
# ...

# %%
# prompt: description ของ row ไหนยาวที่สุด print name และ ความยาว

longest_description = ''
longest_description_name = ''
for index, row in folk_df.iterrows():
  if len(row['description']) > len(longest_description):
    longest_description = row['description']
    longest_description_name = row['title']

print(f'The longest description belongs to "{longest_description_name}" and its length is {len(longest_description)}')
# Out:
# The longest description belongs to "ท้าวหมาหยุ๋ย" and its length is 7825

# %%
# prompt: description ของ row ไหนสั้นที่สุด print name และ ความยาว

shortest_description = None
shortest_description_name = None
for index, row in folk_df.iterrows():
  if shortest_description is None or len(row['description']) < len(shortest_description):
    shortest_description = row['description']
    shortest_description_name = row['title']

print(f'The shortest description belongs to "{shortest_description_name}" and its length is {len(shortest_description)}')
# Out:
# The shortest description belongs to "จักจั่นไม่มีไส้" and its length is 204

# %% [markdown]
# ## HW 5.2

# %%
# prompt: ลบค่าว่างใน column type

folk_df = folk_df.dropna(subset=['type'])

# %%
# prompt: ชนิดของนิทาน (type) ที่มีจำนวน row มากที่สุดและน้อยที่สุด

type_counts = folk_df['type'].value_counts()

most_common_type = type_counts.index[0]
least_common_type = type_counts.index[-1]

print(f"Most common type: {most_common_type}, count: {type_counts[most_common_type]}")
print(f"Least common type: {least_common_type}, count: {type_counts[least_common_type]}")
# Out:
# Most common type: มุขตลก, count: 46
# Least common type: นิทานเข้าแบบ, count: 1

# %% [markdown]
# ### ทำเอง

# %%
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          40       22           40       40       34         0
# นิทานประจำถิ่น      25       14           25       25       23         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          14        5           14       14       11         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              46       31           46       46       42         0
#
#                  language  rights  license  source.uri
# type
# ...

# %% [markdown]
# ### HW 5.3 มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0      มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ...  นิทานพื้นบ้าน     ไทย
# 1     ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครองเม...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
set(folk_df['spatial']) # set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df = folk_df.dropna(subset=['spatial'])

# %%
folk_df.shape[0]
# Out:
# 192

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-avon-and-somerset-stop-and-search.csv')
df.shape
# Out:
# (565, 15)

# %%
df.isnull().head()
# Out:
#     Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0  False  False                          True                True     False
# 1  False  False                          True                True     False
# 2  False  False                          True                True      True
# 3  False  False                          True                True      True
# 4  False  False                          True                True      True
#
#    Longitude  Gender  Age range  Self-defined ethnicity  \
# 0      False   False      False                   False
# 1      False   False      False                   False
# 2       True   False      False                   False
# 3       True   False      False                   False
# 4       True   False      False                   False
#
#    Officer-defined ethnicity  Legislation  Object of search  Outcome  \
# 0                      False        False             False    False
# ...

# %%
df.isnull().any().head()
# Out:
# Type                            False
# Date                            False
# Part of a policing operation     True
# Policing operation               True
# Latitude                         True
# dtype: bool

# %%
df.dropna(subset = ['Self-defined ethnicity','Legislation'])
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T01:49:14+00:00
# 1    Person and Vehicle search  2025-01-01T01:49:14+00:00
# 2                Person search  2025-01-01T02:09:24+00:00
# 3                Person search  2025-01-01T02:09:24+00:00
# 4                Person search  2025-01-01T02:09:24+00:00
# ..                         ...                        ...
# 560              Person search  2025-01-31T18:58:50+00:00
# 561              Person search  2025-01-31T18:58:50+00:00
# 562  Person and Vehicle search  2025-01-31T19:14:19+00:00
# 563  Person and Vehicle search  2025-01-31T19:14:19+00:00
# 564  Person and Vehicle search  2025-01-31T19:14:19+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN  51.491668  -2.492035
# 1                             NaN                 NaN  51.491668  -2.492035
# ...

# %%
df.dropna(subset = ['Self-defined ethnicity','Legislation'],inplace=True)
df.shape
# Out:
# (483, 15)

# %%
df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                 True
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                             True
# Outcome                                      True
# Outcome linked to object of search           True
# Removal of more than just outer clothing     True
# dtype: bool

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) # สมมติ เราต้องใช้ ค่าใน column 'name','description','type'

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
# Out:
#     Type Date Part of a policing operation  Policing operation  Latitude  \
# 0    NaN  NaN                          NaN                 NaN       NaN
# 1    NaN  NaN                          NaN                 NaN       NaN
# 2    NaN  NaN                          NaN                 NaN       NaN
# 3    NaN  NaN                          NaN                 NaN       NaN
# 4    NaN  NaN                          NaN                 NaN       NaN
# ..   ...  ...                          ...                 ...       ...
# 382  NaN  NaN                          NaN                 NaN       NaN
# 383  NaN  NaN                          NaN                 NaN       NaN
# 384  NaN  NaN                          NaN                 NaN       NaN
# 385  NaN  NaN                          NaN                 NaN       NaN
# 386  NaN  NaN                          NaN                 NaN       NaN
#
#      Longitude Gender Age range Self-defined ethnicity  \
# ...

# %%
df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1524751480.py in <cell line: 0>()
# ----> 1 df.fillna()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7291                     )
#    7292
# -> 7293         value, method = validate_fillna_kwargs(value, method)
#    7294         if method is not None:
#    7295             warnings.warn(
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     291
#     292     if value is None and method is None:
# --> 293         raise ValueError("Must specify a fill 'value' or 'method'.")
#     294     if value is None and method is not None:
#     295         method = clean_fill_method(method)
#
# ValueError: Must specify a fill 'value' or 'method'.

# %%
df.fillna('Unknow').isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                          False
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %%
df.fillna({'Gender':'Unkmow'},inplace=True)
df['Gender'].value_counts()
# Out:
# Gender
# Male      400
# Female     75
# Unkmow      8
# Name: count, dtype: int64

# %%
folk_df['type'].mode()
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
df['Gender'].isnull().count()
# Out:
# np.int64(483)

# %%
folk_df['type'].isnull().any()    # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
folk_df['type'].isnull().all()    # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %% [markdown]
# # Quiz 7 นิทานเรื่องไหนที่ ค่า spatial เป็น ค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %%
df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
df.duplicated()==False
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 387, dtype: bool

# %%
# Out:
# [False, True]

# %%
df[~(df.duplicated())]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ### เติมค่าว่างด้วยค่ากลาง

# %%
df['Age range'].mode().iloc[0]
# Out:
# 'over 34'

# %%
df.fillna({'Latitude':df['Latitude'].mean(),
            'Latitude':df['Latitude'].mean(),
            'Age range':df['Age range'].mode().iloc[0]},inplace = True)

# %%
df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                    True
# Gender                                       True
# Age range                                   False
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
df.fillna().
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0    False  False                         False                True     False
# 1    False  False                         False                True     False
# 2    False  False                         False                True     False
# 3    False  False                         False                True     False
# 4    False  False                         False                True     False
# ..     ...    ...                           ...                 ...       ...
# 382  False  False                         False                True     False
# 383  False  False                         False                True     False
# 384  False  False                         False                True     False
# 385  False  False                         False                True     False
# 386  False  False                         False                True     False
#
# ...

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
folk_df['title'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: title, Length: 226, dtype: bool

# %%
folk_df['title'].duplicated().any()
# Out:
# True

# %%
folk_df[folk_df['title'].duplicated(keep=False)]
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.fillna({'type':folk_df['type'].mode()})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %% [markdown]
# ### Age range missing

# %%
df[df['Age range'].isnull()]
# Out:
#                Type                       Date  Part of a policing operation  \
# 6    Vehicle search  2025-01-01T10:00:00+00:00                         False
# 23   Vehicle search  2025-01-03T13:05:00+00:00                          True
# 28   Vehicle search  2025-01-04T14:30:00+00:00                         False
# 40   Vehicle search  2025-01-05T03:25:00+00:00                         False
# 52    Person search  2025-01-06T08:00:00+00:00                         False
# 56   Vehicle search  2025-01-06T16:15:00+00:00                         False
# 61   Vehicle search  2025-01-06T21:33:00+00:00                          True
# 62   Vehicle search  2025-01-06T21:35:00+00:00                          True
# 77    Person search  2025-01-07T15:10:00+00:00                          True
# 83    Person search  2025-01-07T22:31:00+00:00                         False
# 91   Vehicle search  2025-01-08T15:05:00+00:00                         False
# ...

# %%
this_data = folk_df[['title','type','creator']].dropna()

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
this_data = df.iloc[:10,:]

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, Type                                                                            Person search
# Date                                                                2025-01-01T00:35:00+00:00
# Part of a policing operation                                                            False
# Policing operation                                                                        NaN
# Latitude                                                                            51.881481
# Longitude                                                                            -0.41311
# Gender                                                                                   Male
# Age range                                                                               25-34
# Self-defined ethnicity                      Mixed/Multiple ethnic groups - Any other Mixed...
# Officer-defined ethnicity                                                               Other
# ...

# %%
each_row
# Out:
# (9,
#  Type                                                                Person search
#  Date                                                    2025-01-01T15:10:00+00:00
#  Part of a policing operation                                                 True
#  Policing operation                                                            NaN
#  Latitude                                                                51.958279
#  Longitude                                                                     NaN
#  Gender                                                                       Male
#  Age range                                                                 over 34
#  Self-defined ethnicity                         White - Any other White background
#  Officer-defined ethnicity                                                   White
#  Legislation                                 Misuse of Drugs Act 1971 (section 23)
# ...

# %%
for each_row in this_data.iterrows():
    print(each_row[1]['Date'],
          each_row[1]['Self-defined ethnicity'],
          each_row[1]['Legislation'],
          sep = '//',
          end = '********************')
# Out:
# 2025-01-01T00:35:00+00:00//Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background//Police and Criminal Evidence Act 1984 (section 1)********************2025-01-01T02:30:00+00:00//White - English/Welsh/Scottish/Northern Irish/British//Police and Criminal Evidence Act 1984 (section 1)********************2025-01-01T02:30:00+00:00//White - English/Welsh/Scottish/Northern Irish/British//Police and Criminal Evidence Act 1984 (section 1)********************2025-01-01T02:30:00+00:00//White - English/Welsh/Scottish/Northern Irish/British//Police and Criminal Evidence Act 1984 (section 1)********************2025-01-01T02:30:00+00:00//White - English/Welsh/Scottish/Northern Irish/British//Police and Criminal Evidence Act 1984 (section 1)********************2025-01-01T10:00:00+00:00//Other ethnic group - Not stated//Misuse of Drugs Act 1971 (section 23)********************2025-01-01T10:00:00+00:00//nan//Misuse of Drugs Act 1971 (section 23)********************2025-01-01T12:12:
# ...

# %% [markdown]
# ### สร้างตารางใหม่
#
#
# ![download.png](data:image/png;base64,...)

# %%
Price =[
    {'วันที่':'01-09-2568','ชื่อ':'รุ่งแสง','รหัส':'292','ความผิด':'ไม่ใส่หมวกกันน็อค'},
    {'วันที่':'01-09-2568','ชื่อ':'พรพรรณ','รหัส':'277','ความผิด':'ไม่ใส่หมวกกันน็อค'}
]

# %%
kku = pd.DataFrame(Price)

# %%
kku
# Out:
#        วันที่     ชื่อ รหัส            ความผิด
# 0  01-09-2568  รุ่งแสง  292  ไม่ใส่หมวกกันน็อค
# 1  01-09-2568   พรพรรณ  277  ไม่ใส่หมวกกันน็อค

# %% [markdown]
# ### เซฟตาราง

# %%
kku.to_csv('ตำรวจ')
kku.to_excel('ตำรวจ.xlsx',sheet_name='วันที่ 1')

# %% [markdown]
# ### การต่อตาราง

# %% [markdown]
# #### แกน X เพิ่มคอลัมน์ เพิ่มรายละเอียดของข้อมูล

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_outcomes = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-avon-and-somerset-outcomes.csv'
path_to_streets = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-avon-and-somerset-street.csv'

# %%
outcomes = pd.read_csv(path_to_outcomes)
streets = pd.read_csv(path_to_streets)

# %%
outcomes.head(4)
# Out:
#                                             Crime ID    Month  \
# 0  9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1  0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
# 2  ae2635027b0484e1ef028b833ba5a795a3f33104ac9c82...  2025-01
# 3  d4250554f997530722b58740c8679665f3327de2e5b601...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.704043
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.576637
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary        NaN
#
#     Latitude                     Location  LSOA code            LSOA name  \
# 0  51.387847     On or near Downside Road  E01014854  North Somerset 013D
# 1        NaN                  No location        NaN                  NaN
# ...

# %%
streets.head(4)
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
# 2  cf50d7824b02ca548125204807e34491d14de60b1812e7...  2025-01
# 3  63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# 1  51.411782  On or near Westfield Close  E01014399
# 2  51.416147  On or near St Francis Road  E01014399
# 3  51.416147  On or near St Francis Road  E01014399
#
# ...

# %% [markdown]
# #### ต่อแบบเลือกมาเฉพาะบาง column

# %%
streets['Crime ID]'].map(outcomes.set_index('Crime ID')['Outcomes Type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Crime ID]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3291779396.py in <cell line: 0>()
# ...

# %% [markdown]
# #### จาเกิด erroe เมื่อตารางที่เราจะไปเอา data มามี id ที่ duplicate เพราไ่ม่รู้ว่าจะเอาค่าไหนมาแสดง

# %%
outcomes[outcomes.duplicated()==False]
# Out:
#                                                Crime ID    Month  \
# 0     9a6df6be8891d0d563b6e3b8a805f221b134b8eda665ea...  2025-01
# 1     0d99bdcd6594184d351f0513d71635162e9e4a756f1a79...  2025-01
# 2     ae2635027b0484e1ef028b833ba5a795a3f33104ac9c82...  2025-01
# 3     d4250554f997530722b58740c8679665f3327de2e5b601...  2025-01
# 4     5fcb9a243ac6f29f7ef5bcf6d316d8936897ea315220ec...  2025-01
# ...                                                 ...      ...
# 8661  11dda2defc0926781936f0eca22d1f09ecc5a600df3426...  2025-01
# 8662  037e32604f1177888fde385651b72609bfed7e023acd3e...  2025-01
# 8663  1b210f5b90f896c1a99d946a78690dfa1fce33b86c562a...  2025-01
# 8664  d36253be9532b44066d088b854b39fb88820ef35cb2b5f...  2025-01
# 8665  c1a583cfdbbc637ac4bab1066ee6ce470969620fca863f...  2025-01
#
#                          Reported by                    Falls within  \
# 0     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# ...

# %%
outcomes_dedup = outcomes.drop_duplicates(keep='last',subset = ['Crime ID'])

# %% [markdown]
# #### ได้ column ที่ map มาแล้ว

# %%
streets['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3        Unable to prosecute suspect
# 4        Unable to prosecute suspect
#                     ...
# 14823                            NaN
# 14824                            NaN
# 14825                            NaN
# 14826                            NaN
# 14827    Unable to prosecute suspect
# Name: Crime ID, Length: 14828, dtype: object

# %% [markdown]
# #### เพิ่มคอลัมน์ใหม่ในตาราง

# %%
streets['Outcome type'] = streets['Crime ID'].map(outcomes_dedup.set_index('Crime ID')['Outcome type'])
streets.head()
# Out:
#                                             Crime ID    Month  \
# 0  5b3b243f3ae69b761588f65caefe62454587b15576ed55...  2025-01
# 1  1673f50aa688f77cc735d07f47a4f8fcff38d5ebcb70ed...  2025-01
# 2  cf50d7824b02ca548125204807e34491d14de60b1812e7...  2025-01
# 3  63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4  7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -1.084621
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511824
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.508867
#
#     Latitude                    Location  LSOA code  \
# 0  53.251666  On or near Limetree Avenue  E01033769
# ...

# %%
streets[streets['Outcome type'].notnull()]
# Out:
#                                                 Crime ID    Month  \
# 3      63e97874e46f7c886d2d9444741fa4651dac32af835e80...  2025-01
# 4      7d93e2987187429aee7de3cc7d1042f7fe47086821296f...  2025-01
# 5      a57a7ba8444b78c7302e32db62e2c9b10c3d335c49aa2e...  2025-01
# 12     1ab4fc1e8655d08503bac9ad5cb0e4e207bebda6e400ef...  2025-01
# 21     783441401a33b03739d0c968fa9ea7ac28e243b4327bb4...  2025-01
# ...                                                  ...      ...
# 14769  7f15ad082412ec3b54f55db713d3181b580587eeaee348...  2025-01
# 14776  ee0e540e5c03b1d212aa4ed208a5afd0eb0c78e04dc18d...  2025-01
# 14802  0482ea4d7ee6dd67a0ab692e36d7ec1aa6f64b3a259564...  2025-01
# 14818  08565175e093624fb2088014d86916f6cc12906b6a1c4c...  2025-01
# 14827  90859b5ae1578088414e2aa9eb93fb3d1854f9053d7121...  2025-01
#
#                           Reported by                    Falls within  \
# 3      Avon and Somerset Constabulary  Avon and Somerset Constabulary
# ...

# %% [markdown]
# ### แกน Y เพิ่มคอลัมน์ เพิ่มจำนวนของข้อมูล

# %%
Loutcomes1 = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-city-of-london-outcomes.csv')
Loutcomes2 = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-city-of-london-outcomes.csv')
Loutcomes3 = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-03-city-of-london-outcomes.csv')

# %%
print(Loutcomes1.shape)
print(Loutcomes2.shape)
print(Loutcomes3.shape)
# Out:
# (760, 10)
# (566, 10)
# (691, 10)

# %% [markdown]
# #### การต่อตารางแกน Y (map())

# %%
Loutcomes_123 = pd.concat([Loutcomes1,Loutcomes2,Loutcomes3])
Loutcomes_123.shape
# Out:
# (2017, 10)

# %% [markdown]
# ## Group By![Group by.png](data:image/png;base64,...)

# %%
stop_and_search = pd.read_csv('/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-city-of-london-stop-and-search.csv')
stop_and_search.head()
# Out:
#                         Type                       Date  \
# 0  Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1  Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2  Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3  Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4              Person search  2025-01-02T03:19:44+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN        NaN        NaN
# 1                           NaN                 NaN        NaN        NaN
# 2                           NaN                 NaN        NaN        NaN
# 3                           NaN                 NaN        NaN        NaN
# 4                           NaN                 NaN  51.510042  -0.120439
#
#   Gender Age range                           Self-defined ethnicity  \
# 0   Male     18-24                Asian/Asian British - Bangladeshi
# ...

# %%
stop_and_search['Self-defined ethnicity'].value_counts()
# Out:
# Self-defined ethnicity
# Other ethnic group - Not stated                                                         52
# White - English/Welsh/Scottish/Northern Irish/British                                   30
# White - Any other White background                                                      20
# Black/African/Caribbean/Black British - African                                         11
# Asian/Asian British - Bangladeshi                                                        6
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background     6
# Asian/Asian British - Pakistani                                                          6
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background                6
# Asian/Asian British - Any other Asian background                                         5
# Black/African/Caribbean/Black British - Caribbean                                        5
# ...

# %%
stop_and_search.groupby('Self-defined ethnicity').count()
# Out:
#                                                     Type  Date  \
# Self-defined ethnicity
# Asian/Asian British - Any other Asian background       5     5
# Asian/Asian British - Bangladeshi                      6     6
# Asian/Asian British - Indian                           1     1
# Asian/Asian British - Pakistani                        6     6
# Black/African/Caribbean/Black British - African       11    11
# Black/African/Caribbean/Black British - Any oth...     6     6
# Black/African/Caribbean/Black British - Caribbean      5     5
# Mixed/Multiple ethnic groups - Any other Mixed/...     6     6
# Mixed/Multiple ethnic groups - White and Asian         1     1
# Mixed/Multiple ethnic groups - White and Black ...     1     1
# Other ethnic group - Any other ethnic group            4     4
# Other ethnic group - Not stated                       52    52
# White - Any other White background                    20    20
# ...

# %%
stop_and_search.groupby('Self-defined ethnicity').count().reset_index()
# Out:
#                                Self-defined ethnicity  Type  Date  \
# 0    Asian/Asian British - Any other Asian background     5     5
# 1                   Asian/Asian British - Bangladeshi     6     6
# 2                        Asian/Asian British - Indian     1     1
# 3                     Asian/Asian British - Pakistani     6     6
# 4     Black/African/Caribbean/Black British - African    11    11
# 5   Black/African/Caribbean/Black British - Any ot...     6     6
# 6   Black/African/Caribbean/Black British - Caribbean     5     5
# 7   Mixed/Multiple ethnic groups - Any other Mixed...     6     6
# 8      Mixed/Multiple ethnic groups - White and Asian     1     1
# 9   Mixed/Multiple ethnic groups - White and Black...     1     1
# 10        Other ethnic group - Any other ethnic group     4     4
# 11                    Other ethnic group - Not stated    52    52
# 12                 White - Any other White background    20    20
# ...

# %%
stop_and_search.groupby(['Officer-defined ethnicity','Self-defined ethnicity']).count()#.reset_index()
# Out:
#                                                                               Type  \
# Officer-defined ethnicity Self-defined ethnicity
# Asian                     Asian/Asian British - Any other Asian background       4
#                           Asian/Asian British - Bangladeshi                      5
#                           Asian/Asian British - Indian                           1
#                           Asian/Asian British - Pakistani                        6
#                           Mixed/Multiple ethnic groups - Any other Mixed/...     2
#                           Other ethnic group - Not stated                       15
# Black                     Black/African/Caribbean/Black British - African       10
#                           Black/African/Caribbean/Black British - Any oth...     6
#                           Black/African/Caribbean/Black British - Caribbean      5
#                           Mixed/Multiple ethnic groups - Any other Mixed/...     2
# ...

# %% [markdown]
# # Quiz 9
#
# - วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
#
# - มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
#
# - คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด

# %%
# prompt: จาก data this_data วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง

count = 0
stories = []
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    count += 1
    stories.append(row['title'])

print(f"There are {count} stories with 'แม่' or 'พ่อ' in the title.")
print("The stories are:")
for story in stories:
  print(story)
# Out:
# There are 19 stories with 'แม่' or 'พ่อ' in the title.
# The stories are:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
# prompt: มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน บอกจำนวนด้วย

import pandas
import pandas as pd
import os
from google.colab import drive
from bs4 import BeautifulSoup

# ... (preceding code)

count_life = 0
count_local = 0
for index, row in this_data.iterrows():
  if ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานชีวิต':
    count_life += 1
  elif ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานประจำถิ่น':
    count_local += 1

if count_life > count_local:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานชีวิต ({count_life} stories) than in นิทานประจำถิ่น ({count_local} stories).")
elif count_local > count_life:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานประจำถิ่น ({count_local} stories) than in นิทานชีวิต ({count_life} stories).")
else:
  print(f"There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น ({count_life} stories each).")
# Out:
# There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น (2 stories each).

# %%
# prompt: คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด (พร้อมทั้งอธิบาย code แต่ละบรรทัดด้วย)

# สร้าง dictionary เพื่อเก็บจำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องสำหรับแต่ละคนแต่ง
creator_counts = {}
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    creator = row['creator']
    if creator not in creator_counts:
      creator_counts[creator] = 0
    creator_counts[creator] += 1

# หาคนแต่งที่มีจำนวนนิทานมากที่สุด
max_count = 0
most_prolific_creator = None
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    most_prolific_creator = creator

print(f"The creator who wrote the most stories with 'แม่' or 'พ่อ' in the title is {most_prolific_creator} with {max_count} stories.")
# Out:
# The creator who most frequently writes stories with 'แม่' or 'พ่อ' in the title is: หนูเวียง แก้วเวียง
# They have written 2 such stories.

# %%
creator_counts
# Out:
# {'หนูเวียง แก้วเวียง': 2,
#  'สุบิน คำยางจ้อง': 1,
#  'ปรางค์ทิพย์ บุญสีลา': 1,
#  'ชลิตา โพธิสาร': 1,
#  'ไพบูลย์ ระหา': 1,
#  'สุนีย์ คุณโพธิ์': 1,
#  'เสาร์ จันกอ': 2,
#  'จันทร์ โพธิ์ไทสง': 1,
#  'อ่อนตา ประกาเวสา': 2,
#  'สมศรี ถอนภูเขียว': 1,
#  'พรม วรรณศิริ': 1,
#  'สุรพันธ์ บุญชู': 1,
#  'เลิศ ประนัดเด': 1,
#  'อาคม  ปาสานัย': 1,
#  'ลาภ  เพ็ญสวัสดิ์': 1,
#  'นวลจันทร์  จีนเมือง': 1}

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9
# - print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา ใช้ iloc

# ... (preceding code)

for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
# Out:
# เขาปู่เขาย่า

# %% [markdown]
# # Dataset ใหม่ ที่มี ตัวเลข

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: ถ้า dropna ข้อมูลเหลือกี่ %

remaining_percentage = (movie_df.dropna().shape[0] / movie_df.shape[0]) * 100
print(f"Remaining data after dropna: {remaining_percentage:.2f}%")
# Out:
# Remaining data after dropna: 36.49%

# %%
movie_df = movie_df.dropna()

# %%
# prompt: ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข

# ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)

# %%
movie_df.head()
# Out:
#                                  Name  Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019  109 min
# 3                             #Yaaram  2019  110 min
# 5                ...Aur Pyaar Ho Gaya  1997  147 min
# 6                           ...Yahaan  2005  142 min
# 8                  ?: A Question Mark  2012   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %%
movie_df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
# prompt: สร้างตารางของ​ Director ที่มี Name เยอะที่สุด เอาแค่ข้อมูลของคนที่เยอะที่สุด

# นับจำนวนหนังที่แต่ละ Director กำกับ
director_counts = movie_df['Director'].value_counts()

# หา Director ที่กำกับหนังเยอะที่สุด
most_prolific_director = director_counts.index[0]
num_movies = director_counts[0]

# สร้างตารางของ Director ที่กำกับหนังเยอะที่สุด
most_prolific_director_df = movie_df[movie_df['Director'] == most_prolific_director]

# แสดงตาราง
print(f"Director with most movies: {most_prolific_director} ({num_movies} movies)")
most_prolific_director_df
# Out:
# Director with most movies: David Dhawan (41 movies)
#                                     Name  Year  Duration  \
# 239                          Aag Ka Gola  1990       180
# 397                            Aandhiyan  1990       145
# 408                              Aankhen  1993       170
# 1008                               Andaz  1994       167
# 1596              Bade Miyan Chote Miyan  1998       140
# 1794                       Banarasi Babu  1997       126
# 2408                          Biwi No. 1  1999       159
# 2478                       Bol Radha Bol  1992       164
# 2754                      Chal Mere Bhai  2000       136
# 2903                     Chashme Baddoor  2013       121
# 3098                  Chor Machaaye Shor  2002       145
# 3230                        Coolie No. 1  1995       143
# 3232                        Coolie No. 1  2020       134
# 3562                     Deewana Mastana  1997       140
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == most_prolific_director]['Rating'].mean()
# Out:
# 5.226829268292683

# %%
movie_df[movie_df['Director'] == most_prolific_director].describe()
# Out:
#               Year    Duration     Rating
# count    41.000000   41.000000  41.000000
# mean   1999.804878  145.170732   5.226829
# std       7.460628   15.006503   1.060430
# min    1989.000000  121.000000   2.900000
# 25%    1995.000000  134.000000   4.600000
# 50%    1998.000000  143.000000   5.100000
# 75%    2002.000000  160.000000   6.100000
# max    2020.000000  180.000000   6.700000

# %% [markdown]
# # HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง
#
# (พรีเซ็นคนละ 3 นาที slides)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
